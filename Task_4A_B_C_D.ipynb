# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmetA75/Task-4A_B_C_D/blob/main/Task_4A_B_C_D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_excel('Temporary_data3_-_Copy.xlsx').dropna()
data
# Out:
#       SEX  EDUC  MARISTAT  INDEPEND  RESIDENC  NACCFAM  ANYMEDS  SMOKYRS  \
# 0       2    18         1         1         1        1        1        0
# 1       1    11         1         1         1        1        1        0
# 2       2    16         1         1         1        1        1       10
# 3       1    14         1         1         1        0        1        0
# 4       1    16         1         1         2        0        1       50
# ...   ...   ...       ...       ...       ...      ...      ...      ...
# 1349    1    20         1         1         1        1        1        0
# 1350    1    16         1         2         1        0        1        0
# 1351    2    14         2         1         1        1        1        0
# 1352    2    20         3         1         1        1        1       25
# 1353    2    14         1         1         1        1        1       10
#
#       NACCTBI  DIABETES  ...   RSUPFR  RSUPFRM  RSUPPAR  RSUPPARM  RSUPTEM  \
# ...

# %%
data.describe()
# Out:
#                SEX         EDUC     MARISTAT     INDEPEND     RESIDENC  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000
# mean      1.573855    15.223781     1.658789     1.316100     1.112999
# std       0.494698     3.418699     1.136754     0.598538     0.360372
# min       1.000000     0.000000     1.000000     1.000000     1.000000
# 25%       1.000000    12.000000     1.000000     1.000000     1.000000
# 50%       2.000000    16.000000     1.000000     1.000000     1.000000
# 75%       2.000000    18.000000     2.000000     2.000000     1.000000
# max       2.000000    25.000000     6.000000     4.000000     4.000000
#
#            NACCFAM      ANYMEDS      SMOKYRS      NACCTBI     DIABETES  ...  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000  ...
# mean      0.631462     0.952733     9.754801     0.127031     0.192762  ...
# std       0.482586     0.212289    14.351222     0.333131     0.432160  ...
# ...

# %%
data.corr()
# Out:
#                SEX      EDUC  MARISTAT  INDEPEND  RESIDENC   NACCFAM  \
# SEX       1.000000 -0.129742  0.244620 -0.098873  0.054726 -0.005097
# EDUC     -0.129742  1.000000 -0.021607 -0.108642 -0.030139  0.062121
# MARISTAT  0.244620 -0.021607  1.000000 -0.099897  0.101406 -0.034038
# INDEPEND -0.098873 -0.108642 -0.099897  1.000000  0.115258 -0.036503
# RESIDENC  0.054726 -0.030139  0.101406  0.115258  1.000000 -0.057857
# ...            ...       ...       ...       ...       ...       ...
# RSUPTEMM  0.057830  0.041457  0.083243 -0.359562  0.018632 -0.030018
# RSUPMAR  -0.231002  0.184778 -0.022053 -0.143379 -0.084733  0.087566
# RSUPMARM  0.040348  0.145529  0.019383 -0.189939  0.076612  0.074872
# RTRTEM   -0.148505  0.192072 -0.059230 -0.055922 -0.118758  0.114719
# RTRTEMM  -0.008018  0.193395 -0.044063 -0.042208 -0.117984  0.135564
#
#            ANYMEDS   SMOKYRS   NACCTBI  DIABETES  ...    RSUPFR   RSUPFRM  \
# ...

# %%
data.mean()
# Out:
# SEX          1.573855
# EDUC        15.223781
# MARISTAT     1.658789
# INDEPEND     1.316100
# RESIDENC     1.112999
#               ...
# RSUPTEMM     2.119802
# RSUPMAR      8.443465
# RSUPMARM     1.759100
# RTRTEM       0.821142
# RTRTEMM      1.365689
# Length: 192, dtype: float64

# %%
data.std()
# Out:
# SEX         0.494698
# EDUC        3.418699
# MARISTAT    1.136754
# INDEPEND    0.598538
# RESIDENC    0.360372
#               ...
# RSUPTEMM    0.361646
# RSUPMAR     1.533598
# RSUPMARM    0.265813
# RTRTEM      0.236952
# RTRTEMM     0.380721
# Length: 192, dtype: float64

# %%
data.var()
# Out:
# SEX          0.244726
# EDUC        11.687505
# MARISTAT     1.292210
# INDEPEND     0.358248
# RESIDENC     0.129868
#               ...
# RSUPTEMM     0.130788
# RSUPMAR      2.351922
# RSUPMARM     0.070657
# RTRTEM       0.056146
# RTRTEMM      0.144949
# Length: 192, dtype: float64

# %%
data.cov()
# Out:
#                SEX       EDUC  MARISTAT  INDEPEND  RESIDENC   NACCFAM  \
# SEX       0.244726  -0.219422  0.137562 -0.029276  0.009756 -0.001217
# EDUC     -0.219422  11.687505 -0.083971 -0.222305 -0.037131  0.102488
# MARISTAT  0.137562  -0.083971  1.292210 -0.067969  0.041541 -0.018673
# INDEPEND -0.029276  -0.222305 -0.067969  0.358248  0.024861 -0.010544
# RESIDENC  0.009756  -0.037131  0.041541  0.024861  0.129868 -0.010062
# ...            ...        ...       ...       ...       ...       ...
# RSUPTEMM  0.010346   0.051256  0.034222 -0.077830  0.002428 -0.005239
# RSUPMAR  -0.175254   0.968776 -0.038446 -0.131610 -0.046829  0.064807
# RSUPMARM  0.005306   0.132248  0.005857 -0.030219  0.007339  0.009604
# RTRTEM   -0.017408   0.155592 -0.015954 -0.007931 -0.010141  0.013118
# RTRTEMM  -0.001510   0.251717 -0.019070 -0.009618 -0.016188  0.024907
#
#            ANYMEDS   SMOKYRS   NACCTBI  DIABETES  ...    RSUPFR   RSUPFRM  \
# ...

# %%
dt2= pd.DataFrame(data['CDRGLOB'])
dt2
# Out:
#       CDRGLOB
# 0           0
# 1           2
# 2           0
# 3           0
# 4           1
# ...       ...
# 1349        1
# 1350        2
# 1351        0
# 1352        0
# 1353        0
#
# [1354 rows x 1 columns]

# %%
plt.figure()

dt2.plot(kind="box")
plt.show();
# Out:
# ''

# %%
dt2.plot(kind="line");

# %%
dt2.plot(kind="bar")
plt.axhline(100, color="k");

# %%
dt3 = pd.DataFrame(data['CERETISS'])
dt3
# Out:
#       CERETISS
# 0      952.446
# 1      975.620
# 2     1035.400
# 3      965.820
# 4      885.615
# ...        ...
# 1349   989.959
# 1350  1026.640
# 1351   918.530
# 1352   995.230
# 1353   863.900
#
# [1354 rows x 1 columns]

# %%
dt5 = data.groupby('CDRGLOB')[['CERETISS']].plot()
dt5 ;

# %%
plt.hist(dt3, alpha=0.99) ;
plt.hist(dt2, alpha=0.99) ;

# %%
dt2["CERETISS"]=data["CERETISS"]
dt2["DIABETES"]=data["DIABETES"]
dt2["RSUPTEMM"]=data["RSUPTEMM"]
dt2.dropna()
# Out:
#       CDRGLOB  CERETISS  DIABETES  RSUPTEMM
# 0           0   952.446         0    1.7419
# 1           0   975.620         0    2.3000
# 2          10  1035.400         1    2.0700
# 3           0   965.820         1    1.6400
# 4          50   885.615         0    1.6270
# ...       ...       ...       ...       ...
# 1349        0   989.959         0    2.8833
# 1350        0  1026.640         0    1.9027
# 1351        0   918.530         0    1.9900
# 1352       25   995.230         0    2.1000
# 1353       10   863.900         0    2.2000
#
# [1354 rows x 4 columns]

# %%
dt2.corr()
# Out:
#            CDRGLOB  CERETISS  DIABETES  RSUPTEMM
# CDRGLOB   1.000000 -0.046848  0.108207 -0.042994
# CERETISS -0.046848  1.000000 -0.137940  0.116515
# DIABETES  0.108207 -0.137940  1.000000  0.095185
# RSUPTEMM -0.042994  0.116515  0.095185  1.000000

# %%
sns.set()  
data.pivot_table('CDRGLOB', index='SMOKYRS', columns='APA', aggfunc='mean').plot(kind="line")
plt.ylabel('AD_LEVEL');

# %%
ADx = data.pivot_table('HIPPOVOL', index='APA', columns='ALCOHOL', aggfunc='mean')

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ADx.plot(ax=ax);
